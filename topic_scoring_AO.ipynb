# %%
import numpy as np
import pandas as pd
import spacy
import en_core_web_md
nlp = en_core_web_md.load()
import re
import functools
import operator

# %%
from spacy.tokens import Doc
from nltk.sentiment.vader import SentimentIntensityAnalyzer

import plotly

# Set sentiment extensions
sent_analyzer = SentimentIntensityAnalyzer()
def sentiment_scores(docx):
    return sent_analyzer.polarity_scores(docx.text)
Doc.set_extension("sentimenter",getter=sentiment_scores,force=True)

# %%
data = pd.read_csv('data/data_airlinequality.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  Aircraft  Cabin Staff Service     Date Flown Food & Beverages  \
# 0           0       NaN                  5.0   January 2020                1
# 1           1       NaN                  1.0  December 2019                1
# 2           2  A330-300                  4.0   January 2020                4
# 3           3      A320                  2.0   January 2020                1
# 4           4      A321                  4.0  December 2019                4
#
#    Ground Service Inflight Entertainment Recommended  \
# 0             1.0                    NaN          no
# 1             5.0                      2          no
# 2             2.0                      4         yes
# 3             3.0                      1          no
# 4             1.0                    NaN         yes
#
#                            Route  Seat Comfort  ...         country  \
# 0  Prague to Cape Town via Paris           1.0  ...         Germany
# 1               Toronto to Paris           5.0  ...          Canada
# 2               Paris to Chicago           4.0  ...   United States
# 3                Paris to Madrid           1.0  ...           Spain
# 4                Paris to Prague           3.0  ...  Czech Republic
#
#                 date global Food & Beverages  global Inflight Entertainment  \
# 0  23rd January 2020                       3                              3
# 1  23rd January 2020                       3                              3
# 2  17th January 2020                       3                              3
# 3  16th January 2020                       3                              3
# 4   9th January 2020                       3                              3
#
#   global Seat Comfort global Staff Service global Value for Money  \
# 0                   3                    3                      3
# 1                   3                    3                      3
# 2                   3                    3                      3
# 3                   3                    3                      3
# 4                   3                    3                      3
#
#                                               review  \
# 0   Prague to Cape Town via Paris. Very disappoin...
# 1   Toronto to Paris. Brand new plane, very nice ...
# 2   Paris to Chicago. Very attentive, courteous s...
# 3   Paris to Madrid. The product does not corresp...
# 4   Paris to Prague. First of all the passengers ...
#
#                                    title   verification
# 0              never fly with them again  Trip Verified
# 1           pour myself a glass of water  Trip Verified
# 2           attentive, courteous service  Trip Verified
# 3       not correspond to business class  Trip Verified
# 4  checked size and weight of cabin bags  Trip Verified
#
# [5 rows x 25 columns]

# %%
def NLPipe(pandas_columns, n=100):
    
    pandas_columns = pandas_columns.str.replace('[^\w\s]', '')
    docs = list(nlp.pipe(pandas_columns))
    tokens = []
    lemma = []
    pos = []
    dep = []
    ent = []
    
    for doc in docs:
        if doc.is_parsed:
            tokens.append([n.text for n in doc if not n.is_stop])
            #lemma.append([n.lemma_ for n in doc if not n.is_stop])
            #pos.append([n.pos_ for n in doc if not n.is_stop])
            #dep.append([n.dep_ for n in doc if not n.is_stop])
            #ent.append([n.ent_type_ for n in doc if not n.is_stop])
        else:
            # We want to make sure that the lists of parsed results have the
            # same number of entries of the original Dataframe, so add some blanks in case the parse fails
            tokens.append(None)
            #lemma.append(None)
            #pos.append(None)
    
    #df['Tokens'] = tokens
    #df['Lemmas'] = lemma
    #df['POSTags'] = pos
    #df['Dependency'] = dep
    #df['Entity'] = ent
    list_flat = functools.reduce(operator.iconcat, tokens,[])
    top100 = pd.Series(list_flat).value_counts()[:n]
    return top100

# %%
test = NLPipe(data.review, n=100)

# %%
dict_topics = {'Seat': ['seat', 'neck', 'back', 'leg', 'comfort'],
              'Staff Service' : ['staff', 'crew', 'service'],
              'Time' : ['delay', 'time'],
              'Ground Service' : ['check', 'boarding', 'ticket', 'access', 'efficiency'],
              'Food & Beverages' : ['drinks', 'food', 'meal', 'catering'],
              'Aircraft' : ['aircraft', 'cabin', 'luggage', 'cleanliness'],
                'Inflight Entertainment' : ['screen', 'movies', 'entertainment', 'wifi' ]
              }

# %% [markdown]
# ## Test

# %%
df_airlinequality = data.copy()
#set an index
df_airlinequality.rename(columns={'Unnamed: 0' : 'index'}, inplace=True)

# %%
df_sentence_extraction = df_airlinequality.copy()
df_sentence_extraction = df_sentence_extraction[['index', 'review']]
df_sentence_extraction.head(2)
# Out:
#    index                                             review
# 0      0   Prague to Cape Town via Paris. Very disappoin...
# 1      1   Toronto to Paris. Brand new plane, very nice ...

# %%
df_test = df_sentence_extraction.iloc[:100]
df_test.shape
# Out:
# (100, 2)

# %%
for i,v in dict_topics.items():
    print(i,v)
# Out:
# Seat ['seat', 'neck', 'back', 'leg', 'comfort']
# Staff Service ['staff', 'crew', 'service']
# Time ['delay', 'time']
# Ground Service ['check', 'boarding', 'ticket', 'access', 'efficiency']
# Food & Beverages ['drinks', 'food', 'meal', 'catering']
# Aircraft ['aircraft', 'cabin', 'luggagecleanliness']
# Inflight Entertainment ['screen', 'movies', 'entertainment', 'wifi']

# %%
# A helper function to get sentiment of a comment
def get_sentiment(text):
    return nlp(text)._.sentimenter['compound']

def average_score(l_sentences):
    if len(l_sentences) == 0:
        return np.nan
    else:
        l_results = [get_sentiment(text) for text in l_sentences]
        return np.mean(l_results)

#returns a list of sentences if contains a list of words
def find_sentence_if_l_words(txt, l_words):
    seps = ["? ", ". ", "! ", ", "]
    for sep in seps:
        txt = txt.replace(sep, '. ')
    l = [t for t in txt.split('. ') if any(x in t for x in l_words)]
    return l

#returns new features of list of sentence according to words related to a topic
def sentence_extraction_scoring(df_reviews, dict_topics, column_name='review'):
    df = df_reviews.copy()
    for key, l_words in dict_topics.items():
        df[key + '_sentences'] = df.apply(lambda row: find_sentence_if_l_words(row[column_name], l_words), axis=1)
        df[key + '_score'] = df[key + '_sentences'].apply(average_score)
    return df

#returns new features of list of sentence according to words related to a topic
def sentence_extraction(df_reviews, dict_topics, column_name='review'):
    df = df_reviews.copy()
    for key, l_words in dict_topics.items():
        df[key] = df.apply(lambda row: find_sentence_if_l_words(row[column_name], l_words), axis=1)
    return df

# %%
df_results = sentence_extraction(df_test, dict_topics, column_name='review')
df_results.head(2)
# Out:
#    index                                             review  \
# 0      0   Prague to Cape Town via Paris. Very disappoin...
# 1      1   Toronto to Paris. Brand new plane, very nice ...
#
#                                                 Seat  \
# 0                                                 []
# 1  [I was in the middle seat and I didn't want to...
#
#                                        Staff Service Time Ground Service  \
# 0  [very friendly staff, I was told by airport st...   []             []
# 1                                                 []   []             []
#
#                                     Food & Beverages Aircraft  \
# 0  [but my food was not nice When I arrived in Ca...       []
# 1                                                 []       []
#
#                          Inflight Entertainment
# 0                                            []
# 1  [very nice screens and everything was clean]

# %%
df_results_2 = sentence_extraction_scoring(df_test, dict_topics, column_name='review')
df_results_2.head()
# Out:
#    index                                             review  \
# 0      0   Prague to Cape Town via Paris. Very disappoin...
# 1      1   Toronto to Paris. Brand new plane, very nice ...
# 2      2   Paris to Chicago. Very attentive, courteous s...
# 3      3   Paris to Madrid. The product does not corresp...
# 4      4   Paris to Prague. First of all the passengers ...
#
#                                       Seat_sentences  Seat_score  \
# 0                                                 []         NaN
# 1  [I was in the middle seat and I didn't want to...    0.068567
# 2                                                 []         NaN
# 3  [The seats are the same as in the economy, the...    0.143733
# 4                                                 []         NaN
#
#                              Staff Service_sentences  Staff Service_score  \
# 0  [very friendly staff, I was told by airport st...              0.27065
# 1                                                 []                  NaN
# 2  [courteous service in flight by the cabin crew...              0.51060
# 3  [The staff responds to requests, Wines in smal...              0.28235
# 4                                    [crew was nice]              0.42150
#
#              Time_sentences  Time_score  \
# 0                        []         NaN
# 1                        []         NaN
# 2                        []         NaN
# 3                        []         NaN
# 4  [The flight was on time]         0.0
#
#                             Ground Service_sentences  Ground Service_score  \
# 0                                                 []                   NaN
# 1                                                 []                   NaN
# 2                                                 []                   NaN
# 3                                                 []                   NaN
# 4  [First of all the passengers are checked for s...               -0.1892
#
#                           Food & Beverages_sentences  Food & Beverages_score  \
# 0  [but my food was not nice When I arrived in Ca...                 -0.4585
# 1                                                 []                     NaN
# 2                                                 []                     NaN
# 3  [The food is scarce and tasteless - two cold s...                  0.0000
# 4                                                 []                     NaN
#
#                                   Aircraft_sentences  Aircraft_score  \
# 0                                                 []             NaN
# 1                                                 []             NaN
# 2  [courteous service in flight by the cabin crew...          0.5106
# 3                                                 []             NaN
# 4  [First of all the passengers are checked for s...         -0.1892
#
#                     Inflight Entertainment_sentences  \
# 0                                                 []
# 1       [very nice screens and everything was clean]
# 2                                                 []
# 3                                                 []
# 4  [There was a wifi with free message pass which...
#
#    Inflight Entertainment_score
# 0                           NaN
# 1                        0.6997
# 2                           NaN
# 3                           NaN
# 4                        0.8126

# %%
column_test = df_results['Seat_sentences']
column_test[:3]
# Out:
# 0                                                   []
# 1    [I was in the middle seat and I didn't want to...
# 2                                                   []
# Name: Seat_sentences, dtype: object

# %%
from topic_scoring import sentence_extraction_scoring

# %%
df_results_2 = sentence_extraction_scoring(df_test, dict_topics, column_name='review')

# %%
df_results_2
# Out:
#     index                                             review  \
# 0       0   Prague to Cape Town via Paris. Very disappoin...
# 1       1   Toronto to Paris. Brand new plane, very nice ...
# 2       2   Paris to Chicago. Very attentive, courteous s...
# 3       3   Paris to Madrid. The product does not corresp...
# 4       4   Paris to Prague. First of all the passengers ...
# ..    ...                                                ...
# 95      5   Paris to Shanghai. It could be better. Comfor...
# 96      6   Madrid to Johannesburg via Paris. Air France'...
# 97      7  Check-in started three and half hours before t...
# 98      8  Flight from LHR to CDG was an unmemorable, sta...
# 99      9   Bangkok to Aberdeen via Paris. I am pleasantl...
#
#                                        Seat_sentences  Seat_score  \
# 0                                                  []         NaN
# 1   [I was in the middle seat and I didn't want to...    0.068567
# 2                                                  []         NaN
# 3   [The seats are the same as in the economy, the...    0.143733
# 4                                                  []         NaN
# ..                                                ...         ...
# 95                              [Comfortable seating]    0.510600
# 96  [Also no compensation for having paid extra €8...   -0.296000
# 97  [AF's premium economy seat is in a hard shell ...   -0.003725
# 98  [The seat is rather strange as it is a hard sh...    0.058050
# 99                                                 []         NaN
#
#                               Staff Service_sentences  Staff Service_score  \
# 0   [very friendly staff, I was told by airport st...              0.27065
# 1                                                  []                  NaN
# 2   [courteous service in flight by the cabin crew...              0.51060
# 3   [The staff responds to requests, Wines in smal...              0.28235
# 4                                     [crew was nice]              0.42150
# ..                                                ...                  ...
# 95                                                 []                  NaN
# 96  [Air France's customer service is the worst I'...             -0.03330
# 97  [The crew on this flight were very french and ...              0.00000
# 98  [The crew was friendly and attentive and they ...              0.64860
# 99  [All the flight attendants was very pleasant a...              0.86870
#
#                                        Time_sentences  Time_score  \
# 0                                                  []         NaN
# 1                                                  []         NaN
# 2                                                  []         NaN
# 3                                                  []         NaN
# 4                            [The flight was on time]     0.00000
# ..                                                ...         ...
# 95  [Pressing the flight attendant call button 5 t...    -0.02745
# 96  [Having been delayed for a total of 26 hours t...    -0.73510
# 97                         [Boarding started on time]     0.00000
# 98  [We landed on time at DXB in the old terminal ...     0.26170
# 99                                                 []         NaN
#
#                              Ground Service_sentences  Ground Service_score  \
# 0                                                  []                   NaN
# 1                                                  []                   NaN
# 2                                                  []                   NaN
# 3                                                  []                   NaN
# 4   [First of all the passengers are checked for s...               -0.1892
# ..                                                ...                   ...
# 95                                                 []                   NaN
# 96  [no information at the disembarking gate to sa...               -0.6249
# 97  [Premium economy passengers are allowed to use...                0.4404
# 98                                                 []                   NaN
# 99                                                 []                   NaN
#
#                            Food & Beverages_sentences  Food & Beverages_score  \
# 0   [but my food was not nice When I arrived in Ca...                 -0.4585
# 1                                                  []                     NaN
# 2                                                  []                     NaN
# 3   [The food is scarce and tasteless - two cold s...                  0.0000
# 4                                                  []                     NaN
# ..                                                ...                     ...
# 95                                                 []                     NaN
# 96                                                 []                     NaN
# 97                                                 []                     NaN
# 98                                     [The food was]                  0.0000
# 99                                                 []                     NaN
#
#                                    Aircraft_sentences  Aircraft_score  \
# 0                                                  []             NaN
# 1                                                  []             NaN
# 2   [courteous service in flight by the cabin crew...          0.5106
# 3                                                  []             NaN
# 4   [First of all the passengers are checked for s...         -0.1892
# ..                                                ...             ...
# 95                                     [New aircraft]          0.0000
# 96                                                 []             NaN
# 97  [Like the journey to DXB the PE cabin was in n...          0.3612
# 98  [Generally the cabin looked very tired and in ...         -0.4927
# 99                                                 []             NaN
#
#                      Inflight Entertainment_sentences  \
# 0                                                  []
# 1        [very nice screens and everything was clean]
# 2                                                  []
# 3                                                  []
# 4   [There was a wifi with free message pass which...
# ..                                                ...
# 95        [In flight entertainment is pretty not bad]
# 96                                                 []
# 97  [The IFE system was ok but the choices seemed ...
# 98  [The in-flight entertainment selection was not...
# 99                                                 []
#
#     Inflight Entertainment_score
# 0                            NaN
# 1                         0.6997
# 2                            NaN
# 3                            NaN
# 4                         0.8126
# ..                           ...
# 95                        0.8338
# 96                           NaN
# 97                       -0.1901
# 98                        0.2946
# 99                           NaN
#
# [100 rows x 16 columns]
